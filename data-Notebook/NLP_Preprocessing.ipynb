# %%
import pandas as pd
df =pd.read_csv("clean_jobs.csv")
print(df.shape)
# Out:
# (7996, 17)

# %%
print(df["clean_description"].iloc[0])
# Out:
# job description send me jobs like this qualifications 10th to graduation any skill basic computer knowledge job requirement system or laptop type of job full time or part time languages tamil english experience freshers experience payment details 1 form per day 5 10 form per day 50 100 form per day 500 monthly you can earn 15000 per month selection process easy selection process so what are you waiting for apply now grab best opportunity to make your carrier to improve your earing skills more detail contact mr hari salary inr 1 50 000 2 25 000 p a industry media entertainment internet functional area ites bpo kpo lpo customer service operations role category other role fresher keyskills english typing part time data entry selection process desired candidate profile education ug b tech b e any specialization pg any postgraduate any specialization post graduation not required please refer to the job description above company profile mm media pvt ltd mass media international find live info pvt ltd data services is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing find live info is one of our main project it is a developing search engine site based at chennai india with years of experience we have crafted massive data collection job opportunities for public find live info a blend of experience imagination strategy and action to create digital experience that excite challenge inspire and engage users find live info provides other business opportunities which will be handled by experts of various fields we have interesting combination of young and experienced specialists under the guidance of our top management we bloom towards success more detail contect download ppt photo 1 view contact details

# %% [markdown]
# # Tokenization

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

df= pd.read_csv("clean_jobs.csv")
text = df["clean_description"].iloc[0]
print("Original Text:")
print(text)
# Out:
# Original Text:
# job description send me jobs like this qualifications 10th to graduation any skill basic computer knowledge job requirement system or laptop type of job full time or part time languages tamil english experience freshers experience payment details 1 form per day 5 10 form per day 50 100 form per day 500 monthly you can earn 15000 per month selection process easy selection process so what are you waiting for apply now grab best opportunity to make your carrier to improve your earing skills more detail contact mr hari salary inr 1 50 000 2 25 000 p a industry media entertainment internet functional area ites bpo kpo lpo customer service operations role category other role fresher keyskills english typing part time data entry selection process desired candidate profile education ug b tech b e any specialization pg any postgraduate any specialization post graduation not required please refer to the job description above company profile mm media pvt ltd mass media international find live info pvt ltd data services is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing find live info is one of our main project it is a developing search engine site based at chennai india with years of experience we have crafted massive data collection job opportunities for public find live info a blend of experience imagination strategy and action to create digital experience that excite challenge inspire and engage users find live info provides other business opportunities which will be handled by experts of various fields we have interesting combination of young and experienced specialists under the guidance of our top management we bloom towards success more detail contect download ppt photo 1 view contact details

# %%
tokens = word_tokenize(text)
print("\nTOKENS:")
print(tokens)
# Out:
# TOKENS:
# ['job', 'description', 'send', 'me', 'jobs', 'like', 'this', 'qualifications', '10th', 'to', 'graduation', 'any', 'skill', 'basic', 'computer', 'knowledge', 'job', 'requirement', 'system', 'or', 'laptop', 'type', 'of', 'job', 'full', 'time', 'or', 'part', 'time', 'languages', 'tamil', 'english', 'experience', 'freshers', 'experience', 'payment', 'details', '1', 'form', 'per', 'day', '5', '10', 'form', 'per', 'day', '50', '100', 'form', 'per', 'day', '500', 'monthly', 'you', 'can', 'earn', '15000', 'per', 'month', 'selection', 'process', 'easy', 'selection', 'process', 'so', 'what', 'are', 'you', 'waiting', 'for', 'apply', 'now', 'grab', 'best', 'opportunity', 'to', 'make', 'your', 'carrier', 'to', 'improve', 'your', 'earing', 'skills', 'more', 'detail', 'contact', 'mr', 'hari', 'salary', 'inr', '1', '50', '000', '2', '25', '000', 'p', 'a', 'industry', 'media', 'entertainment', 'internet', 'functional', 'area', 'ites', 'bpo', 'kpo', 'lpo', 'customer', 'service', 'operations', 'role', 'category', 'other', 'role', 'fresher', 'keyskills', 'english', 'typing', 'part', 'time', 'data', 'entry', 'selection', 'process', 'desired', 'candidate', 'profile', 'education', 'ug', 'b', 'tech', 'b', 'e', 'any', 'specialization', 'pg', 'any', 'postgraduate', 'any', 'specialization', 'post', 'graduation', 'not', 'required', 'please', 'refer', 'to', 'the', 'job', 'description', 'above', 'company', 'profile', 'mm', 'media', 'pvt', 'ltd', 'mass', 'media', 'international', 'find', 'live', 'info', 'pvt', 'ltd', 'data', 'services', 'is', 'established', 'in', 'the', 'year', '2012', 'with', 'a', 'vision', 'of', 'transforming', 'an', 'ordinary', 'to', 'extra', 'ordinary', 'thing', 'find', 'live', 'info', 'is', 'one', 'of', 'our', 'main', 'project', 'it', 'is', 'a', 'developing', 'search', 'engine', 'site', 'based', 'at', 'chennai', 'india', 'with', 'years', 'of', 'experience', 'we', 'have', 'crafted', 'massive', 'data', 'collection', 'job', 'opportunities', 'for', 'public', 'find', 'live', 'info', 'a', 'blend', 'of', 'experience', 'imagination', 'strategy', 'and', 'action', 'to', 'create', 'digital', 'experience', 'that', 'excite', 'challenge', 'inspire', 'and', 'engage', 'users', 'find', 'live', 'info', 'provides', 'other', 'business', 'opportunities', 'which', 'will', 'be', 'handled', 'by', 'experts', 'of', 'various', 'fields', 'we', 'have', 'interesting', 'combination', 'of', 'young', 'and', 'experienced', 'specialists', 'under', 'the', 'guidance', 'of', 'our', 'top', 'management', 'we', 'bloom', 'towards', 'success', 'more', 'detail', 'contect', 'download', 'ppt', 'photo', '1', 'view', 'contact', 'details']

# %%
# LowerCase
lower_text = text.lower()
print("\nLOWERCASE:")
print(lower_text)
# Out:
# LOWERCASE:
# job description send me jobs like this qualifications 10th to graduation any skill basic computer knowledge job requirement system or laptop type of job full time or part time languages tamil english experience freshers experience payment details 1 form per day 5 10 form per day 50 100 form per day 500 monthly you can earn 15000 per month selection process easy selection process so what are you waiting for apply now grab best opportunity to make your carrier to improve your earing skills more detail contact mr hari salary inr 1 50 000 2 25 000 p a industry media entertainment internet functional area ites bpo kpo lpo customer service operations role category other role fresher keyskills english typing part time data entry selection process desired candidate profile education ug b tech b e any specialization pg any postgraduate any specialization post graduation not required please refer to the job description above company profile mm media pvt ltd mass media international find live info pvt ltd data services is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing find live info is one of our main project it is a developing search engine site based at chennai india with years of experience we have crafted massive data collection job opportunities for public find live info a blend of experience imagination strategy and action to create digital experience that excite challenge inspire and engage users find live info provides other business opportunities which will be handled by experts of various fields we have interesting combination of young and experienced specialists under the guidance of our top management we bloom towards success more detail contect download ppt photo 1 view contact details

# %%
# Remove stepwords
stop_words = set(stopwords.words("english"))
filtered_tokens = [
    word for word in tokens
    if word.lower() not in stop_words
]
print("\nAFTER STOPWORDS REMOVAL:")
print(filtered_tokens)
# Out:
# AFTER STOPWORDS REMOVAL:
# ['job', 'description', 'send', 'jobs', 'like', 'qualifications', '10th', 'graduation', 'skill', 'basic', 'computer', 'knowledge', 'job', 'requirement', 'system', 'laptop', 'type', 'job', 'full', 'time', 'part', 'time', 'languages', 'tamil', 'english', 'experience', 'freshers', 'experience', 'payment', 'details', '1', 'form', 'per', 'day', '5', '10', 'form', 'per', 'day', '50', '100', 'form', 'per', 'day', '500', 'monthly', 'earn', '15000', 'per', 'month', 'selection', 'process', 'easy', 'selection', 'process', 'waiting', 'apply', 'grab', 'best', 'opportunity', 'make', 'carrier', 'improve', 'earing', 'skills', 'detail', 'contact', 'mr', 'hari', 'salary', 'inr', '1', '50', '000', '2', '25', '000', 'p', 'industry', 'media', 'entertainment', 'internet', 'functional', 'area', 'ites', 'bpo', 'kpo', 'lpo', 'customer', 'service', 'operations', 'role', 'category', 'role', 'fresher', 'keyskills', 'english', 'typing', 'part', 'time', 'data', 'entry', 'selection', 'process', 'desired', 'candidate', 'profile', 'education', 'ug', 'b', 'tech', 'b', 'e', 'specialization', 'pg', 'postgraduate', 'specialization', 'post', 'graduation', 'required', 'please', 'refer', 'job', 'description', 'company', 'profile', 'mm', 'media', 'pvt', 'ltd', 'mass', 'media', 'international', 'find', 'live', 'info', 'pvt', 'ltd', 'data', 'services', 'established', 'year', '2012', 'vision', 'transforming', 'ordinary', 'extra', 'ordinary', 'thing', 'find', 'live', 'info', 'one', 'main', 'project', 'developing', 'search', 'engine', 'site', 'based', 'chennai', 'india', 'years', 'experience', 'crafted', 'massive', 'data', 'collection', 'job', 'opportunities', 'public', 'find', 'live', 'info', 'blend', 'experience', 'imagination', 'strategy', 'action', 'create', 'digital', 'experience', 'excite', 'challenge', 'inspire', 'engage', 'users', 'find', 'live', 'info', 'provides', 'business', 'opportunities', 'handled', 'experts', 'various', 'fields', 'interesting', 'combination', 'young', 'experienced', 'specialists', 'guidance', 'top', 'management', 'bloom', 'towards', 'success', 'detail', 'contect', 'download', 'ppt', 'photo', '1', 'view', 'contact', 'details']

# %%
# Lemmatization

lemmatizer = WordNetLemmatizer()
lemmatized_words = [
    lemmatizer.lemmatize(word)
    for word in filtered_tokens
]
print("\nLEMMATIZATION:")
print(lemmatized_words)
# Out:
# LEMMATIZATION:
# ['job', 'description', 'send', 'job', 'like', 'qualification', '10th', 'graduation', 'skill', 'basic', 'computer', 'knowledge', 'job', 'requirement', 'system', 'laptop', 'type', 'job', 'full', 'time', 'part', 'time', 'language', 'tamil', 'english', 'experience', 'fresher', 'experience', 'payment', 'detail', '1', 'form', 'per', 'day', '5', '10', 'form', 'per', 'day', '50', '100', 'form', 'per', 'day', '500', 'monthly', 'earn', '15000', 'per', 'month', 'selection', 'process', 'easy', 'selection', 'process', 'waiting', 'apply', 'grab', 'best', 'opportunity', 'make', 'carrier', 'improve', 'earing', 'skill', 'detail', 'contact', 'mr', 'hari', 'salary', 'inr', '1', '50', '000', '2', '25', '000', 'p', 'industry', 'medium', 'entertainment', 'internet', 'functional', 'area', 'ites', 'bpo', 'kpo', 'lpo', 'customer', 'service', 'operation', 'role', 'category', 'role', 'fresher', 'keyskills', 'english', 'typing', 'part', 'time', 'data', 'entry', 'selection', 'process', 'desired', 'candidate', 'profile', 'education', 'ug', 'b', 'tech', 'b', 'e', 'specialization', 'pg', 'postgraduate', 'specialization', 'post', 'graduation', 'required', 'please', 'refer', 'job', 'description', 'company', 'profile', 'mm', 'medium', 'pvt', 'ltd', 'mass', 'medium', 'international', 'find', 'live', 'info', 'pvt', 'ltd', 'data', 'service', 'established', 'year', '2012', 'vision', 'transforming', 'ordinary', 'extra', 'ordinary', 'thing', 'find', 'live', 'info', 'one', 'main', 'project', 'developing', 'search', 'engine', 'site', 'based', 'chennai', 'india', 'year', 'experience', 'crafted', 'massive', 'data', 'collection', 'job', 'opportunity', 'public', 'find', 'live', 'info', 'blend', 'experience', 'imagination', 'strategy', 'action', 'create', 'digital', 'experience', 'excite', 'challenge', 'inspire', 'engage', 'user', 'find', 'live', 'info', 'provides', 'business', 'opportunity', 'handled', 'expert', 'various', 'field', 'interesting', 'combination', 'young', 'experienced', 'specialist', 'guidance', 'top', 'management', 'bloom', 'towards', 'success', 'detail', 'contect', 'download', 'ppt', 'photo', '1', 'view', 'contact', 'detail']

# %%
# Stemming
stemmer = PorterStemmer()
stemmed_words =[
    stemmer.stem(word)
    for word in filtered_tokens
]
print("\nSTEMMING:")
print(stemmed_words)
# Out:
# STEMMING:
# ['job', 'descript', 'send', 'job', 'like', 'qualif', '10th', 'graduat', 'skill', 'basic', 'comput', 'knowledg', 'job', 'requir', 'system', 'laptop', 'type', 'job', 'full', 'time', 'part', 'time', 'languag', 'tamil', 'english', 'experi', 'fresher', 'experi', 'payment', 'detail', '1', 'form', 'per', 'day', '5', '10', 'form', 'per', 'day', '50', '100', 'form', 'per', 'day', '500', 'monthli', 'earn', '15000', 'per', 'month', 'select', 'process', 'easi', 'select', 'process', 'wait', 'appli', 'grab', 'best', 'opportun', 'make', 'carrier', 'improv', 'ear', 'skill', 'detail', 'contact', 'mr', 'hari', 'salari', 'inr', '1', '50', '000', '2', '25', '000', 'p', 'industri', 'media', 'entertain', 'internet', 'function', 'area', 'ite', 'bpo', 'kpo', 'lpo', 'custom', 'servic', 'oper', 'role', 'categori', 'role', 'fresher', 'keyskil', 'english', 'type', 'part', 'time', 'data', 'entri', 'select', 'process', 'desir', 'candid', 'profil', 'educ', 'ug', 'b', 'tech', 'b', 'e', 'special', 'pg', 'postgradu', 'special', 'post', 'graduat', 'requir', 'pleas', 'refer', 'job', 'descript', 'compani', 'profil', 'mm', 'media', 'pvt', 'ltd', 'mass', 'media', 'intern', 'find', 'live', 'info', 'pvt', 'ltd', 'data', 'servic', 'establish', 'year', '2012', 'vision', 'transform', 'ordinari', 'extra', 'ordinari', 'thing', 'find', 'live', 'info', 'one', 'main', 'project', 'develop', 'search', 'engin', 'site', 'base', 'chennai', 'india', 'year', 'experi', 'craft', 'massiv', 'data', 'collect', 'job', 'opportun', 'public', 'find', 'live', 'info', 'blend', 'experi', 'imagin', 'strategi', 'action', 'creat', 'digit', 'experi', 'excit', 'challeng', 'inspir', 'engag', 'user', 'find', 'live', 'info', 'provid', 'busi', 'opportun', 'handl', 'expert', 'variou', 'field', 'interest', 'combin', 'young', 'experienc', 'specialist', 'guidanc', 'top', 'manag', 'bloom', 'toward', 'success', 'detail', 'contect', 'download', 'ppt', 'photo', '1', 'view', 'contact', 'detail']

# %%
# Sentence segmentation
sentences = sent_tokenize(text)
print("\nSENTENCES:")
for sentence in sentences:
    print(sentence)
# Out:
# SENTENCES:
# job description send me jobs like this qualifications 10th to graduation any skill basic computer knowledge job requirement system or laptop type of job full time or part time languages tamil english experience freshers experience payment details 1 form per day 5 10 form per day 50 100 form per day 500 monthly you can earn 15000 per month selection process easy selection process so what are you waiting for apply now grab best opportunity to make your carrier to improve your earing skills more detail contact mr hari salary inr 1 50 000 2 25 000 p a industry media entertainment internet functional area ites bpo kpo lpo customer service operations role category other role fresher keyskills english typing part time data entry selection process desired candidate profile education ug b tech b e any specialization pg any postgraduate any specialization post graduation not required please refer to the job description above company profile mm media pvt ltd mass media international find live info pvt ltd data services is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing find live info is one of our main project it is a developing search engine site based at chennai india with years of experience we have crafted massive data collection job opportunities for public find live info a blend of experience imagination strategy and action to create digital experience that excite challenge inspire and engage users find live info provides other business opportunities which will be handled by experts of various fields we have interesting combination of young and experienced specialists under the guidance of our top management we bloom towards success more detail contect download ppt photo 1 view contact details

# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (3.8.16)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (0.27.1)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (8.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (4.70.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (84.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from spacy) (26.3)
# Requirement already satisfied: colorama in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from click<9.0.0,>=8.2.1->spacy) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.7.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.14.2)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.21.0)
# Requirement already satisfied: wrapt in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\documents\dataanalyticstask\jobdescriptionproject\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

print("spaCy is ready!")
# Out:
# spaCy is ready!

# %%
import pandas as pd
import spacy

nlp = spacy.load("en_core_web_sm")
df = pd.read_csv("clean_jobs.csv")
text = df["clean_description"].iloc[0]

print(text)
# Out:
# job description send me jobs like this qualifications 10th to graduation any skill basic computer knowledge job requirement system or laptop type of job full time or part time languages tamil english experience freshers experience payment details 1 form per day 5 10 form per day 50 100 form per day 500 monthly you can earn 15000 per month selection process easy selection process so what are you waiting for apply now grab best opportunity to make your carrier to improve your earing skills more detail contact mr hari salary inr 1 50 000 2 25 000 p a industry media entertainment internet functional area ites bpo kpo lpo customer service operations role category other role fresher keyskills english typing part time data entry selection process desired candidate profile education ug b tech b e any specialization pg any postgraduate any specialization post graduation not required please refer to the job description above company profile mm media pvt ltd mass media international find live info pvt ltd data services is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing find live info is one of our main project it is a developing search engine site based at chennai india with years of experience we have crafted massive data collection job opportunities for public find live info a blend of experience imagination strategy and action to create digital experience that excite challenge inspire and engage users find live info provides other business opportunities which will be handled by experts of various fields we have interesting combination of young and experienced specialists under the guidance of our top management we bloom towards success more detail contect download ppt photo 1 view contact details

# %%
# tokennization
doc = nlp(text)
tokens = [token.text for token in doc]
print(tokens[:50])

# Lemmatization
for token in doc[:30]:
    print(token.text, "->", token.lemma_)
# Out:
# ['job', 'description', 'send', 'me', 'jobs', 'like', 'this', 'qualifications', '10th', 'to', 'graduation', 'any', 'skill', 'basic', 'computer', 'knowledge', 'job', 'requirement', 'system', 'or', 'laptop', 'type', 'of', 'job', 'full', 'time', 'or', 'part', 'time', 'languages', 'tamil', 'english', 'experience', 'freshers', 'experience', 'payment', 'details', '1', 'form', 'per', 'day', '5', '10', 'form', 'per', 'day', '50', '100', 'form', 'per']
# job -> job
# description -> description
# send -> send
# me -> I
# jobs -> job
# like -> like
# this -> this
# qualifications -> qualification
# 10th -> 10th
# to -> to
# graduation -> graduation
# any -> any
# skill -> skill
# basic -> basic
# computer -> computer
# knowledge -> knowledge
# job -> job
# requirement -> requirement
# system -> system
# or -> or
# laptop -> laptop
# type -> type
# of -> of
# job -> job
# full -> full
# time -> time
# or -> or
# part -> part
# time -> time
# languages -> language

# %%
# stopword removal
filtered_tokens=[
    token.text 
    for token in doc
    if not token.is_stop
]
print(filtered_tokens[:50])
# Out:
# ['job', 'description', 'send', 'jobs', 'like', 'qualifications', '10th', 'graduation', 'skill', 'basic', 'computer', 'knowledge', 'job', 'requirement', 'system', 'laptop', 'type', 'job', 'time', 'time', 'languages', 'tamil', 'english', 'experience', 'freshers', 'experience', 'payment', 'details', '1', 'form', 'day', '5', '10', 'form', 'day', '50', '100', 'form', 'day', '500', 'monthly', 'earn', '15000', 'month', 'selection', 'process', 'easy', 'selection', 'process', 'waiting']

# %%
text = df["jobdescription"].iloc[0]

doc = nlp(text)

for i, sentence in enumerate(doc.sents, 1):
    print(f"Sentence {i}: {sentence.text}")
# Out:
# Sentence 1: Job Description   Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == >
# Sentence 2: Full Time or Part time Languages : - == > Tamil & English.
# Sentence 3: Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For?
# Sentence 4: Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills.
# Sentence 5: More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES , BPO , KPO , LPO , Customer Service , Operations Role Category:Other Role:Fresher Keyskills English Typing Part Time Data Entry Selection Process Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required Please refer to the Job description above Company Profile: MM Media Pvt Ltd Mass Media International Find Live Info Pvt Ltd DATA SERVICES is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing.
# Sentence 6: Find live info is one of our main project, it is a developing search engine site based at Chennai, India.
# Sentence 7: With years of experience, we have crafted massive data collection job opportunities for public.
# Sentence 8: FIND LIVE INFO a blend of experience, imagination, strategy and action to create digital experience that excite, challenge, inspire and engage users.
# Sentence 9: FIND LIVE INFO provides other business opportunities which will be handled by experts of various fields.
# Sentence 10: We have interesting combination of young and experienced Specialists Under the guidance of our Top Management we bloom towards success More detail contect 8678902528 Download PPT Photo 1   View Contact Details
